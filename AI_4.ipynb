# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ANURAG
# [nltk_data]     KOKITKAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\ANURAG
# [nltk_data]     KOKITKAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ANURAG KOKITKAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = """
Artificial Intelligence is transforming the world.
AI helps in automation, healthcare, education, and business.
"""

tokens = word_tokenize(text)

print("tokenize words\n")
print(tokens)

freq = FreqDist(tokens)
print("frequency words\n")
print(freq)


stop_words = set(stopwords.words('english'))

filtered_word = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_word.append(word)

print("\nAfter Removing Stop Words:\n")
print(filtered_words)


tag = pos_tag(filtered_word)
print("tags words\n")
print(tag)
# Out:
# tokenize words
#
# ['Artificial', 'Intelligence', 'is', 'transforming', 'the', 'world', '.', 'AI', 'helps', 'in', 'automation', ',', 'healthcare', ',', 'education', ',', 'and', 'business', '.']
# frequency words
#
# <FreqDist with 16 samples and 19 outcomes>
#
# After Removing Stop Words:
#
# ['Artificial', 'Intelligence', 'transforming', 'world', '.', 'AI', 'helps', 'automation', ',', 'healthcare', ',', 'education', ',', 'business', '.']
# tags words
#
# [('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('transforming', 'NN'), ('world', 'NN'), ('.', '.'), ('AI', 'NNP'), ('helps', 'VBZ'), ('automation', 'NN'), (',', ','), ('healthcare', 'NN'), (',', ','), ('education', 'NN'), (',', ','), ('business', 'NN'), ('.', '.')]
